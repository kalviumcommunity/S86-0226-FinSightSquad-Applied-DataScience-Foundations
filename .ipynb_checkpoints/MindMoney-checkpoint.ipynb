# %% [markdown]
# ## Hello

# %% [raw]
# This is my first code in Jupyter

# %%
print("hello world")
# Out:
# hello world

# %%
print("Jupyter is working correctly.")
# Out:
# Jupyter is working correctly.
