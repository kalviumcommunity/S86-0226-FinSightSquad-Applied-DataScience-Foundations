# %% [markdown]
# # Markdown Documentation Demo
#
# ## Introduction
#
# This notebook demonstrates how to use Markdown for clear documentation in Jupyter Notebooks.

# %% [markdown]
# ## Step 1: Define Variables

# %% [markdown]
# ### Goals of This Notebook
#
# - Demonstrate Markdown headings
# - Show ordered and unordered lists
# - Format inline code
# - Add code blocks

# %% [markdown]
# ### Steps Performed
#
# 1. Define variables
# 2. Perform a simple calculation
# 3. Display the result
# 4. Interpret the output

# %% [markdown]
# We define a variable called `x` and assign it a value.

# %% [markdown]
# Example of Python syntax:
#
# ```python
# x = 10
# y = 5
# result = x + y

# %%
x = 10
y = 20
result = x + y
result
# Out:
# 30

# %% [markdown]
# The output shows that the sum of `x` and `y` is 15.
#
# This confirms that the addition was performed correctly.
